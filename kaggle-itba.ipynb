# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.layers import Input, Embedding, Flatten, Dropout, Concatenate, Dense, Activation, Lambda
from keras import Model
from keras.regularizers import l2
from keras.optimizers import Adam

# %%
ratings = pd.read_csv('./data/train.csv', sep='\t')

items = pd.read_csv('./data/item.csv', sep='|', encoding = "ISO-8859-1")

user = pd.read_csv('./data/user.csv', sep='|', encoding = "ISO-8859-1")

occupation = pd.read_csv('./data/occupation.csv', sep='|', encoding = "ISO-8859-1")

genre = pd.read_csv('./data/genre.csv', sep='\t', encoding = "ISO-8859-1")

# %%
u_unique = ratings.userId.unique()
user2Idx = {o:i+1 for i,o in enumerate(u_unique)}

m_unique = ratings.movieId.unique()
movie2Idx = {o:i+1 for i,o in enumerate(m_unique)}

idx2Movie = {v:k for k,v in movie2Idx.items()}

# %%
ratings.userId = ratings.userId.apply(lambda x: user2Idx[x])
ratings.movieId = ratings.movieId.apply(lambda x: movie2Idx[x])
ratings['timestamp'] = ratings['timestamp']/max(ratings['timestamp'])

ratings_train, ratings_val = train_test_split(ratings, test_size=0.2)

# %%
n_users = int(ratings.userId.nunique())
n_movies = int(ratings.movieId.nunique())
n_users_train = int(ratings_train.userId.nunique())
n_movies_train = int(ratings_train.movieId.nunique())
max_rating = ratings_train['rating'].max()
min_rating = ratings_train['rating'].min()
av_rating = ratings_train['rating'].mean()
n_latent_factors_user = 8
n_latent_factors_movie = 8
print(n_users, n_movies, n_users_train, n_movies_train)
# Out:
# 943 1650 943 1626

# %%
#timestamp_input = Input(shape=[1],name='timestamp')
movie_input = Input(shape=[1],name='Item')
movie_embedding = Embedding(n_movies + 1, n_latent_factors_movie, name='Movie-Embedding', embeddings_regularizer = l2(0.001))(movie_input)
movie_vec = Flatten(name='FlattenMovies')(movie_embedding)
movie_vec = Dropout(0.2)(movie_vec)


user_input = Input(shape=[1],name='User')
user_vec = Flatten(name='FlattenUsers')(Embedding(n_users + 1, n_latent_factors_user,name='User-Embedding', embeddings_regularizer = l2(0.001))(user_input))
user_vec = Dropout(0.2)(user_vec)


concat = Concatenate(name='Concat')([movie_vec, user_vec])
concat = Dropout(0.2)(concat)

x = Dense(50,name='FullyConnected-1', activation='relu', kernel_regularizer=l2(0.001))(concat)
x = Dropout(0.5)(x)
x = Dense(50,name='FullyConnected-1', activation='relu')(concat)
x = Dropout(0.5)(x)


## Se pueden sacar las siguientes dos lineas para no forzar a sigmoidea
x = Dense(1, activation='sigmoid',name='Activation')(x)
x = Lambda(lambda z: (max_rating - min_rating) * z + min_rating)(x)
##

model = Model([user_input, movie_input], x)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Item (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# User (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# Movie-Embedding (Embedding)     (None, 1, 8)         13208       Item[0][0]
# __________________________________________________________________________________________________
# User-Embedding (Embedding)      (None, 1, 8)         7552        User[0][0]
# __________________________________________________________________________________________________
# FlattenMovies (Flatten)         (None, 8)            0           Movie-Embedding[0][0]
# __________________________________________________________________________________________________
# FlattenUsers (Flatten)          (None, 8)            0           User-Embedding[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8)            0           FlattenMovies[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8)            0           FlattenUsers[0][0]
# __________________________________________________________________________________________________
# Concat (Concatenate)            (None, 16)           0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16)           0           Concat[0][0]
# __________________________________________________________________________________________________
# FullyConnected-1 (Dense)        (None, 50)           850         dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 50)           0           FullyConnected-1[0][0]
# __________________________________________________________________________________________________
# Activation (Dense)              (None, 1)            51          dropout_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1)            0           Activation[0][0]
# ==================================================================================================
# Total params: 21,661
# Trainable params: 21,661
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import keras.backend as K 
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
adam = Adam(lr=0.001)
model.compile(optimizer=adam,loss= 'mean_squared_error', metrics=[root_mean_squared_error])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath='weights1.hdf5', verbose=1, save_best_only=True, monitor='val_root_mean_squared_error')

# %%
history = model.fit([ratings_train.userId, ratings_train.movieId], 
                    ratings_train.rating, 
                    validation_data=([ratings_val.userId, ratings_val.movieId], ratings_val.rating), 
                    batch_size = 160,
                    callbacks = [checkpointer],
                    epochs=100,
                    verbose=2)
# Out:
# /Users/matias/opt/anaconda3/envs/deep_learning/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 64000 samples, validate on 16000 samples
# Epoch 1/100
#  - 6s - loss: 1.1217 - root_mean_squared_error: 1.0504 - val_loss: 0.9188 - val_root_mean_squared_error: 0.9482
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.94824, saving model to weights1.hdf5
# Epoch 2/100
#  - 4s - loss: 0.9585 - root_mean_squared_error: 0.9669 - val_loss: 0.8974 - val_root_mean_squared_error: 0.9334
#
# Epoch 00002: val_root_mean_squared_error improved from 0.94824 to 0.93338, saving model to weights1.hdf5
# Epoch 3/100
#  - 4s - loss: 0.9410 - root_mean_squared_error: 0.9553 - val_loss: 0.8934 - val_root_mean_squared_error: 0.9294
#
# Epoch 00003: val_root_mean_squared_error improved from 0.93338 to 0.92943, saving model to weights1.hdf5
# Epoch 4/100
#  - 3s - loss: 0.9344 - root_mean_squared_error: 0.9504 - val_loss: 0.8933 - val_root_mean_squared_error: 0.9283
#
# Epoch 00004: val_root_mean_squared_error improved from 0.92943 to 0.92829, saving model to weights1.hdf5
# Epoch 5/100
#  - 4s - loss: 0.9285 - root_mean_squared_error: 0.9467 - val_loss: 0.8923 - val_root_mean_squared_error: 0.9270
#
# Epoch 00005: val_root_mean_squared_error improved from 0.92829 to 0.92703, saving model to weights1.hdf5
# Epoch 6/100
#  - 3s - loss: 0.9239 - root_mean_squared_error: 0.9436 - val_loss: 0.8916 - val_root_mean_squared_error: 0.9261
#
# Epoch 00006: val_root_mean_squared_error improved from 0.92703 to 0.92611, saving model to weights1.hdf5
# Epoch 7/100
#  - 3s - loss: 0.9220 - root_mean_squared_error: 0.9419 - val_loss: 0.8882 - val_root_mean_squared_error: 0.9240
#
# Epoch 00007: val_root_mean_squared_error improved from 0.92611 to 0.92396, saving model to weights1.hdf5
# Epoch 8/100
#  - 3s - loss: 0.9193 - root_mean_squared_error: 0.9404 - val_loss: 0.8870 - val_root_mean_squared_error: 0.9229
#
# Epoch 00008: val_root_mean_squared_error improved from 0.92396 to 0.92291, saving model to weights1.hdf5
# Epoch 9/100
#  - 3s - loss: 0.9198 - root_mean_squared_error: 0.9403 - val_loss: 0.8892 - val_root_mean_squared_error: 0.9239
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.92291
# Epoch 10/100
#  - 4s - loss: 0.9158 - root_mean_squared_error: 0.9380 - val_loss: 0.8868 - val_root_mean_squared_error: 0.9224
#
# Epoch 00010: val_root_mean_squared_error improved from 0.92291 to 0.92237, saving model to weights1.hdf5
# Epoch 11/100
#  - 3s - loss: 0.9150 - root_mean_squared_error: 0.9375 - val_loss: 0.8857 - val_root_mean_squared_error: 0.9216
#
# Epoch 00011: val_root_mean_squared_error improved from 0.92237 to 0.92162, saving model to weights1.hdf5
# Epoch 12/100
#  - 3s - loss: 0.9194 - root_mean_squared_error: 0.9395 - val_loss: 0.8882 - val_root_mean_squared_error: 0.9229
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.92162
# Epoch 13/100
#  - 4s - loss: 0.9156 - root_mean_squared_error: 0.9374 - val_loss: 0.8874 - val_root_mean_squared_error: 0.9223
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.92162
# Epoch 14/100
#  - 4s - loss: 0.9150 - root_mean_squared_error: 0.9372 - val_loss: 0.8879 - val_root_mean_squared_error: 0.9225
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.92162
# Epoch 15/100
#  - 3s - loss: 0.9146 - root_mean_squared_error: 0.9368 - val_loss: 0.8864 - val_root_mean_squared_error: 0.9217
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.92162
# Epoch 16/100
#  - 3s - loss: 0.9170 - root_mean_squared_error: 0.9378 - val_loss: 0.8883 - val_root_mean_squared_error: 0.9226
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.92162
# Epoch 17/100
#  - 3s - loss: 0.9135 - root_mean_squared_error: 0.9361 - val_loss: 0.8874 - val_root_mean_squared_error: 0.9221
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.92162
# Epoch 18/100
#  - 4s - loss: 0.9147 - root_mean_squared_error: 0.9365 - val_loss: 0.8899 - val_root_mean_squared_error: 0.9233
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.92162
# Epoch 19/100
#  - 3s - loss: 0.9154 - root_mean_squared_error: 0.9369 - val_loss: 0.8901 - val_root_mean_squared_error: 0.9236
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.92162
# Epoch 20/100
#  - 3s - loss: 0.9145 - root_mean_squared_error: 0.9365 - val_loss: 0.8914 - val_root_mean_squared_error: 0.9241
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.92162
# Epoch 21/100
#  - 4s - loss: 0.9137 - root_mean_squared_error: 0.9362 - val_loss: 0.8884 - val_root_mean_squared_error: 0.9225
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.92162
# Epoch 22/100
#  - 3s - loss: 0.9125 - root_mean_squared_error: 0.9355 - val_loss: 0.8893 - val_root_mean_squared_error: 0.9230
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.92162
# Epoch 23/100
#  - 4s - loss: 0.9118 - root_mean_squared_error: 0.9348 - val_loss: 0.8871 - val_root_mean_squared_error: 0.9218
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.92162
# Epoch 24/100
#  - 4s - loss: 0.9141 - root_mean_squared_error: 0.9365 - val_loss: 0.8887 - val_root_mean_squared_error: 0.9227
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.92162
# Epoch 25/100
#  - 4s - loss: 0.9130 - root_mean_squared_error: 0.9356 - val_loss: 0.8880 - val_root_mean_squared_error: 0.9223
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.92162
# Epoch 26/100
#  - 4s - loss: 0.9106 - root_mean_squared_error: 0.9343 - val_loss: 0.8894 - val_root_mean_squared_error: 0.9231
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.92162
# Epoch 27/100
#  - 4s - loss: 0.9123 - root_mean_squared_error: 0.9354 - val_loss: 0.8889 - val_root_mean_squared_error: 0.9226
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.92162
# Epoch 28/100
#  - 5s - loss: 0.9144 - root_mean_squared_error: 0.9365 - val_loss: 0.8859 - val_root_mean_squared_error: 0.9210
#
# Epoch 00028: val_root_mean_squared_error improved from 0.92162 to 0.92095, saving model to weights1.hdf5
# Epoch 29/100
#  - 4s - loss: 0.9120 - root_mean_squared_error: 0.9350 - val_loss: 0.8864 - val_root_mean_squared_error: 0.9212
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.92095
# Epoch 30/100
#  - 4s - loss: 0.9148 - root_mean_squared_error: 0.9365 - val_loss: 0.8892 - val_root_mean_squared_error: 0.9229
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.92095
# Epoch 31/100
#  - 4s - loss: 0.9103 - root_mean_squared_error: 0.9343 - val_loss: 0.8874 - val_root_mean_squared_error: 0.9219
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.92095
# Epoch 32/100
#  - 4s - loss: 0.9130 - root_mean_squared_error: 0.9355 - val_loss: 0.8876 - val_root_mean_squared_error: 0.9221
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.92095
# Epoch 33/100
#  - 4s - loss: 0.9120 - root_mean_squared_error: 0.9352 - val_loss: 0.8867 - val_root_mean_squared_error: 0.9215
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.92095
# Epoch 34/100
#  - 4s - loss: 0.9104 - root_mean_squared_error: 0.9342 - val_loss: 0.8889 - val_root_mean_squared_error: 0.9228
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.92095
# Epoch 35/100
#  - 4s - loss: 0.9114 - root_mean_squared_error: 0.9346 - val_loss: 0.8899 - val_root_mean_squared_error: 0.9232
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.92095
# Epoch 36/100
#  - 4s - loss: 0.9089 - root_mean_squared_error: 0.9332 - val_loss: 0.8897 - val_root_mean_squared_error: 0.9231
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.92095
# Epoch 37/100
#  - 4s - loss: 0.9123 - root_mean_squared_error: 0.9353 - val_loss: 0.8900 - val_root_mean_squared_error: 0.9232
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.92095
# Epoch 38/100
#  - 4s - loss: 0.9150 - root_mean_squared_error: 0.9367 - val_loss: 0.8890 - val_root_mean_squared_error: 0.9227
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.92095
# Epoch 39/100
#  - 4s - loss: 0.9119 - root_mean_squared_error: 0.9350 - val_loss: 0.8906 - val_root_mean_squared_error: 0.9235
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.92095
# Epoch 40/100
#  - 4s - loss: 0.9112 - root_mean_squared_error: 0.9345 - val_loss: 0.8905 - val_root_mean_squared_error: 0.9234
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.92095
# Epoch 41/100
#  - 4s - loss: 0.9104 - root_mean_squared_error: 0.9339 - val_loss: 0.8913 - val_root_mean_squared_error: 0.9240
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.92095
# Epoch 42/100
#  - 4s - loss: 0.9137 - root_mean_squared_error: 0.9359 - val_loss: 0.8909 - val_root_mean_squared_error: 0.9237
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.92095
# Epoch 43/100
#  - 4s - loss: 0.9097 - root_mean_squared_error: 0.9336 - val_loss: 0.8905 - val_root_mean_squared_error: 0.9235
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.92095
# Epoch 44/100
#  - 4s - loss: 0.9133 - root_mean_squared_error: 0.9356 - val_loss: 0.8877 - val_root_mean_squared_error: 0.9220
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.92095
# Epoch 45/100
#  - 4s - loss: 0.9119 - root_mean_squared_error: 0.9348 - val_loss: 0.8908 - val_root_mean_squared_error: 0.9236
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.92095
# Epoch 46/100
#  - 4s - loss: 0.9134 - root_mean_squared_error: 0.9358 - val_loss: 0.8888 - val_root_mean_squared_error: 0.9225
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.92095
# Epoch 47/100
#  - 4s - loss: 0.9112 - root_mean_squared_error: 0.9345 - val_loss: 0.8888 - val_root_mean_squared_error: 0.9224
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.92095
# Epoch 48/100
#  - 4s - loss: 0.9126 - root_mean_squared_error: 0.9351 - val_loss: 0.8865 - val_root_mean_squared_error: 0.9213
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.92095
# Epoch 49/100
#  - 4s - loss: 0.9129 - root_mean_squared_error: 0.9356 - val_loss: 0.8903 - val_root_mean_squared_error: 0.9234
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.92095
# Epoch 50/100
#  - 5s - loss: 0.9131 - root_mean_squared_error: 0.9354 - val_loss: 0.8875 - val_root_mean_squared_error: 0.9218
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.92095
# Epoch 51/100
#  - 4s - loss: 0.9127 - root_mean_squared_error: 0.9353 - val_loss: 0.8865 - val_root_mean_squared_error: 0.9212
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.92095
# Epoch 52/100
#  - 4s - loss: 0.9137 - root_mean_squared_error: 0.9357 - val_loss: 0.8862 - val_root_mean_squared_error: 0.9211
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.92095
# Epoch 53/100
#  - 6s - loss: 0.9115 - root_mean_squared_error: 0.9346 - val_loss: 0.8882 - val_root_mean_squared_error: 0.9220
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.92095
# Epoch 54/100
#  - 6s - loss: 0.9103 - root_mean_squared_error: 0.9340 - val_loss: 0.8911 - val_root_mean_squared_error: 0.9236
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.92095
# Epoch 55/100
#  - 5s - loss: 0.9110 - root_mean_squared_error: 0.9343 - val_loss: 0.8875 - val_root_mean_squared_error: 0.9217
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.92095
# Epoch 56/100
#  - 4s - loss: 0.9113 - root_mean_squared_error: 0.9346 - val_loss: 0.8872 - val_root_mean_squared_error: 0.9215
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.92095
# Epoch 57/100
#  - 6s - loss: 0.9126 - root_mean_squared_error: 0.9353 - val_loss: 0.8918 - val_root_mean_squared_error: 0.9241
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.92095
# Epoch 58/100
#  - 5s - loss: 0.9112 - root_mean_squared_error: 0.9347 - val_loss: 0.8859 - val_root_mean_squared_error: 0.9208
#
# Epoch 00058: val_root_mean_squared_error improved from 0.92095 to 0.92081, saving model to weights1.hdf5
# Epoch 59/100
#  - 4s - loss: 0.9151 - root_mean_squared_error: 0.9365 - val_loss: 0.8870 - val_root_mean_squared_error: 0.9214
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.92081
# Epoch 60/100
#  - 4s - loss: 0.9104 - root_mean_squared_error: 0.9337 - val_loss: 0.8834 - val_root_mean_squared_error: 0.9195
#
# Epoch 00060: val_root_mean_squared_error improved from 0.92081 to 0.91950, saving model to weights1.hdf5
# Epoch 61/100
#  - 5s - loss: 0.9129 - root_mean_squared_error: 0.9354 - val_loss: 0.8883 - val_root_mean_squared_error: 0.9222
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.91950
# Epoch 62/100
#  - 4s - loss: 0.9103 - root_mean_squared_error: 0.9337 - val_loss: 0.8868 - val_root_mean_squared_error: 0.9214
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.91950
# Epoch 63/100
#  - 4s - loss: 0.9099 - root_mean_squared_error: 0.9336 - val_loss: 0.8882 - val_root_mean_squared_error: 0.9222
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.91950
# Epoch 64/100
#  - 4s - loss: 0.9122 - root_mean_squared_error: 0.9350 - val_loss: 0.8884 - val_root_mean_squared_error: 0.9223
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.91950
# Epoch 65/100
#  - 6s - loss: 0.9098 - root_mean_squared_error: 0.9335 - val_loss: 0.8895 - val_root_mean_squared_error: 0.9228
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.91950
# Epoch 66/100
#  - 6s - loss: 0.9103 - root_mean_squared_error: 0.9341 - val_loss: 0.8878 - val_root_mean_squared_error: 0.9220
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.91950
# Epoch 67/100
#  - 5s - loss: 0.9110 - root_mean_squared_error: 0.9343 - val_loss: 0.8875 - val_root_mean_squared_error: 0.9217
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.91950
# Epoch 68/100
#  - 5s - loss: 0.9089 - root_mean_squared_error: 0.9332 - val_loss: 0.8912 - val_root_mean_squared_error: 0.9237
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.91950
# Epoch 69/100
#  - 6s - loss: 0.9104 - root_mean_squared_error: 0.9339 - val_loss: 0.8867 - val_root_mean_squared_error: 0.9213
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.91950
# Epoch 70/100
#  - 5s - loss: 0.9111 - root_mean_squared_error: 0.9343 - val_loss: 0.8881 - val_root_mean_squared_error: 0.9218
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.91950
# Epoch 71/100
#  - 5s - loss: 0.9122 - root_mean_squared_error: 0.9348 - val_loss: 0.8874 - val_root_mean_squared_error: 0.9215
#
# Epoch 00071: val_root_mean_squared_error did not improve from 0.91950
# Epoch 72/100
#  - 5s - loss: 0.9116 - root_mean_squared_error: 0.9345 - val_loss: 0.8869 - val_root_mean_squared_error: 0.9212
#
# Epoch 00072: val_root_mean_squared_error did not improve from 0.91950
# Epoch 73/100
#  - 6s - loss: 0.9113 - root_mean_squared_error: 0.9343 - val_loss: 0.8851 - val_root_mean_squared_error: 0.9203
#
# Epoch 00073: val_root_mean_squared_error did not improve from 0.91950
# Epoch 74/100
#  - 6s - loss: 0.9091 - root_mean_squared_error: 0.9332 - val_loss: 0.8873 - val_root_mean_squared_error: 0.9215
#
# Epoch 00074: val_root_mean_squared_error did not improve from 0.91950
# Epoch 75/100
#  - 5s - loss: 0.9144 - root_mean_squared_error: 0.9361 - val_loss: 0.8881 - val_root_mean_squared_error: 0.9220
#
# Epoch 00075: val_root_mean_squared_error did not improve from 0.91950
# Epoch 76/100
#  - 6s - loss: 0.9124 - root_mean_squared_error: 0.9349 - val_loss: 0.8877 - val_root_mean_squared_error: 0.9218
#
# Epoch 00076: val_root_mean_squared_error did not improve from 0.91950
# Epoch 77/100
#  - 7s - loss: 0.9106 - root_mean_squared_error: 0.9341 - val_loss: 0.8877 - val_root_mean_squared_error: 0.9217
#
# Epoch 00077: val_root_mean_squared_error did not improve from 0.91950
# Epoch 78/100
#  - 6s - loss: 0.9112 - root_mean_squared_error: 0.9344 - val_loss: 0.8853 - val_root_mean_squared_error: 0.9204
#
# Epoch 00078: val_root_mean_squared_error did not improve from 0.91950
# Epoch 79/100
#  - 6s - loss: 0.9143 - root_mean_squared_error: 0.9358 - val_loss: 0.8896 - val_root_mean_squared_error: 0.9226
#
# Epoch 00079: val_root_mean_squared_error did not improve from 0.91950
# Epoch 80/100
#  - 6s - loss: 0.9130 - root_mean_squared_error: 0.9353 - val_loss: 0.8867 - val_root_mean_squared_error: 0.9213
#
# Epoch 00080: val_root_mean_squared_error did not improve from 0.91950
# Epoch 81/100
#  - 6s - loss: 0.9136 - root_mean_squared_error: 0.9354 - val_loss: 0.8857 - val_root_mean_squared_error: 0.9207
#
# Epoch 00081: val_root_mean_squared_error did not improve from 0.91950
# Epoch 82/100
#  - 7s - loss: 0.9088 - root_mean_squared_error: 0.9333 - val_loss: 0.8889 - val_root_mean_squared_error: 0.9223
#
# Epoch 00082: val_root_mean_squared_error did not improve from 0.91950
# Epoch 83/100
#  - 6s - loss: 0.9115 - root_mean_squared_error: 0.9342 - val_loss: 0.8856 - val_root_mean_squared_error: 0.9207
#
# Epoch 00083: val_root_mean_squared_error did not improve from 0.91950
# Epoch 84/100
#  - 5s - loss: 0.9117 - root_mean_squared_error: 0.9345 - val_loss: 0.8868 - val_root_mean_squared_error: 0.9212
#
# Epoch 00084: val_root_mean_squared_error did not improve from 0.91950
# Epoch 85/100
#  - 6s - loss: 0.9129 - root_mean_squared_error: 0.9353 - val_loss: 0.8848 - val_root_mean_squared_error: 0.9202
#
# Epoch 00085: val_root_mean_squared_error did not improve from 0.91950
# Epoch 86/100
#  - 6s - loss: 0.9111 - root_mean_squared_error: 0.9342 - val_loss: 0.8846 - val_root_mean_squared_error: 0.9200
#
# Epoch 00086: val_root_mean_squared_error did not improve from 0.91950
# Epoch 87/100
#  - 5s - loss: 0.9097 - root_mean_squared_error: 0.9336 - val_loss: 0.8869 - val_root_mean_squared_error: 0.9213
#
# Epoch 00087: val_root_mean_squared_error did not improve from 0.91950
# Epoch 88/100
#  - 4s - loss: 0.9093 - root_mean_squared_error: 0.9335 - val_loss: 0.8845 - val_root_mean_squared_error: 0.9200
#
# Epoch 00088: val_root_mean_squared_error did not improve from 0.91950
# Epoch 89/100
#  - 4s - loss: 0.9145 - root_mean_squared_error: 0.9361 - val_loss: 0.8877 - val_root_mean_squared_error: 0.9218
#
# Epoch 00089: val_root_mean_squared_error did not improve from 0.91950
# Epoch 90/100
#  - 4s - loss: 0.9114 - root_mean_squared_error: 0.9345 - val_loss: 0.8871 - val_root_mean_squared_error: 0.9214
#
# Epoch 00090: val_root_mean_squared_error did not improve from 0.91950
# Epoch 91/100
#  - 6s - loss: 0.9147 - root_mean_squared_error: 0.9362 - val_loss: 0.8877 - val_root_mean_squared_error: 0.9217
#
# Epoch 00091: val_root_mean_squared_error did not improve from 0.91950
# Epoch 92/100
#  - 7s - loss: 0.9076 - root_mean_squared_error: 0.9323 - val_loss: 0.8878 - val_root_mean_squared_error: 0.9216
#
# Epoch 00092: val_root_mean_squared_error did not improve from 0.91950
# Epoch 93/100
#  - 5s - loss: 0.9115 - root_mean_squared_error: 0.9345 - val_loss: 0.8889 - val_root_mean_squared_error: 0.9223
#
# Epoch 00093: val_root_mean_squared_error did not improve from 0.91950
# Epoch 94/100
#  - 6s - loss: 0.9096 - root_mean_squared_error: 0.9335 - val_loss: 0.8861 - val_root_mean_squared_error: 0.9208
#
# Epoch 00094: val_root_mean_squared_error did not improve from 0.91950
# Epoch 95/100
#  - 5s - loss: 0.9097 - root_mean_squared_error: 0.9334 - val_loss: 0.8860 - val_root_mean_squared_error: 0.9207
#
# Epoch 00095: val_root_mean_squared_error did not improve from 0.91950
# Epoch 96/100
#  - 5s - loss: 0.9111 - root_mean_squared_error: 0.9342 - val_loss: 0.8883 - val_root_mean_squared_error: 0.9220
#
# Epoch 00096: val_root_mean_squared_error did not improve from 0.91950
# Epoch 97/100
#  - 5s - loss: 0.9101 - root_mean_squared_error: 0.9334 - val_loss: 0.8904 - val_root_mean_squared_error: 0.9229
#
# Epoch 00097: val_root_mean_squared_error did not improve from 0.91950
# Epoch 98/100
#  - 5s - loss: 0.9126 - root_mean_squared_error: 0.9348 - val_loss: 0.8878 - val_root_mean_squared_error: 0.9215
#
# Epoch 00098: val_root_mean_squared_error did not improve from 0.91950
# Epoch 99/100
#  - 6s - loss: 0.9098 - root_mean_squared_error: 0.9334 - val_loss: 0.8896 - val_root_mean_squared_error: 0.9226
#
# Epoch 00099: val_root_mean_squared_error did not improve from 0.91950
# Epoch 100/100
#  - 7s - loss: 0.9110 - root_mean_squared_error: 0.9342 - val_loss: 0.8861 - val_root_mean_squared_error: 0.9207
#
# Epoch 00100: val_root_mean_squared_error did not improve from 0.91950

# %%
model.evaluate([ratings_val.userId, ratings_val.movieId], ratings_val.rating)
# Out:
# 16000/16000 [==============================] - 1s 51us/step
# [0.8861045098900795, 0.9141870737075806]

# %%
ratings_test = pd.read_csv('./data/test.csv', sep=',')
ratings_test
# Out:
#           Id  userId  movieId  rating
# 0          0       1        6       3
# 1          1       1       10       3
# 2          2       1       12       3
# 3          3       1       14       2
# 4          4       1       17       4
# ...      ...     ...      ...     ...
# 19995  19995     458      648       0
# 19996  19996     458     1101       0
# 19997  19997     459      934       2
# 19998  19998     460       10       0
# 19999  19999     462      682       0
#
# [20000 rows x 4 columns]

# %%
model.load_weights('weights1.hdf5')
y_pred_test = model.predict([ratings_test.userId, ratings_test.movieId], verbose=1)
# Out:
# 20000/20000 [==============================] - 1s 52us/step

# %%
sample_csv = pd.read_csv('data/test.csv')
sample_csv['rating'] = y_pred_test
sample_csv.head()

sample_csv.to_csv(f'submision1.csv', index=False)
